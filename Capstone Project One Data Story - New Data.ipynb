# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\darre\OneDrive\Desktop\NYC_Airbnb_New_Data.csv', index_col = 0)
df.head(5)
# Out:
#                                            name  host_id    host_name  \
# id
# 2595                      Skylit Midtown Castle     2845     Jennifer
# 3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 5121                            BlissArtsSpace!     7356        Garon
# 5178           Large Furnished Room Near B'way      8967     Shunichi
#
#      neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# 2595           Manhattan             Midtown  40.75362  -73.98377
# 3831            Brooklyn        Clinton Hill  40.68514  -73.95976
# 5099           Manhattan         Murray Hill  40.74767  -73.97500
# 5121            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 5178           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#             room_type  price  calculated_host_listings_count  ... bedrooms  \
# id                                                            ...
# 2595  Entire home/apt    225                               2  ...      0.0
# 3831  Entire home/apt     89                               1  ...      1.0
# 5099  Entire home/apt    200                               1  ...      1.0
# 5121     Private room     60                               1  ...      1.0
# 5178     Private room     79                               1  ...      1.0
#
#      beds  minimum_nights  maximum_nights  number_of_reviews  first_review  \
# id
# 2595  1.0               7            1125                 48    11/21/2009
# 3831  4.0               1             730                307     9/30/2014
# 5099  1.0               3              21                 78     4/20/2009
# 5121  1.0              29             730                 50     5/28/2009
# 5178  1.0               2              14                463      5/6/2009
#
#       last_review  review_scores_rating  reviews_per_month availability_365
# id
# 2595    11/4/2019                  94.0               0.39              365
# 3831     2/8/2020                  90.0               4.69              137
# 5099   10/13/2019                  90.0               0.59                0
# 5121    12/2/2019                  90.0               0.38              365
# 5178    1/28/2020                  84.0               3.53              216
#
# [5 rows x 24 columns]

# %%
#To check measures of central tendencies mean, median, and mode, check min and max values and quantiles of each feature.
df.describe()
# Out:
#             host_id      latitude     longitude         price  \
# count  5.109700e+04  51097.000000  51097.000000  51097.000000
# mean   8.307383e+07     40.729068    -73.950761    160.240503
# std    9.551620e+07      0.054970      0.047756    373.633875
# min    2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.407818e+06     40.689650    -73.983120     69.000000
# 50%    3.770355e+07     40.723320    -73.955130    105.000000
# 75%    1.364547e+08     40.763120    -73.933870    175.000000
# max    3.353940e+08     40.914290    -73.712990  10000.000000
#
#        calculated_host_listings_count  accommodates     bathrooms  \
# count                    51097.000000  51097.000000  51050.000000
# mean                         7.605398      2.857506      1.144887
# std                         33.007385      1.885145      0.422976
# min                          1.000000      1.000000      0.000000
# 25%                          1.000000      2.000000      1.000000
# 50%                          1.000000      2.000000      1.000000
# 75%                          2.000000      4.000000      1.000000
# max                        293.000000     22.000000     15.500000
#
#            bedrooms          beds  minimum_nights  maximum_nights  \
# count  51022.000000  50757.000000    51097.000000    5.109700e+04
# mean       1.179922      1.541856        7.451905    4.340860e+04
# std        0.758123      1.132508       21.600604    9.501005e+06
# min        0.000000      0.000000        1.000000    1.000000e+00
# 25%        1.000000      1.000000        1.000000    2.800000e+01
# 50%        1.000000      1.000000        2.000000    7.300000e+02
# 75%        1.000000      2.000000        5.000000    1.125000e+03
# max       21.000000     40.000000     1250.000000    2.147484e+09
#
#        number_of_reviews  review_scores_rating  reviews_per_month  \
# count       51097.000000          39778.000000       40749.000000
# mean           25.053819             93.866509           1.319523
# std            48.433410              8.830803           1.625829
# min             0.000000             20.000000           0.010000
# 25%             1.000000             92.000000           0.190000
# 50%             6.000000             96.000000           0.680000
# 75%            25.000000            100.000000           1.970000
# max           690.000000            100.000000          63.510000
#
#        availability_365
# count      51097.000000
# mean         117.438049
# std          134.887735
# min            0.000000
# 25%            0.000000
# 50%           58.000000
# 75%          230.000000
# max          365.000000

# %%
df = df.rename (
    columns={
        'name':'Title',
        'host_id':'Host Id',
        'host_name':'Host Name',
        'neighbourhood_group':'Neighborhood Group',
        'neighbourhood':'Neighborhood',
        'latitude':'Latitude',
        'longitude': 'Longitude',
        'room_type': 'Room Type',
        'price': 'Price',
        'calculated_host_listings_count': 'Number of Listings by Host',
        'property_type': 'Property Type',
        'room_type': 'Room Type',
        'accomodates': 'Accommodates',
        'bathrooms': 'Number of Bathrooms',
        'bedrooms': 'Number of Bedrooms',
        'beds': 'Number of Beds',
        'minimum_nights': 'Minimum Nights',
        'maximum_nights': 'Maximum Nights',
        'number_of_reviews': 'Number of Reviews',
        'first_review': 'First Reviewed',
        'last_review': 'Last Reviewed',
        'review_scores_rating': 'Rating',
        'reviews_per_month': 'Reviews Per Month',
        'availability_365': 'Availability',})

# %%
#As we can see from the data below there are quite a few null entries in the 'Last Reviewed' and 'Reviews per Month' columns.
#Along with those columns there are some null entries in Title, and Host Name.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51097 entries, 2595 to 42231486
# Data columns (total 24 columns):
# Title                         51080 non-null object
# Host Id                       51097 non-null int64
# Host Name                     51091 non-null object
# Neighborhood Group            51097 non-null object
# Neighborhood                  51097 non-null object
# Latitude                      51097 non-null float64
# Longitude                     51097 non-null float64
# Room Type                     51097 non-null object
# Price                         51097 non-null int64
# Number of Listings by Host    51097 non-null int64
# Property Type                 51097 non-null object
# room_type.1                   51097 non-null object
# accommodates                  51097 non-null int64
# Number of Bathrooms           51050 non-null float64
# Number of Bedrooms            51022 non-null float64
# Number of Beds                50757 non-null float64
# Minimum Nights                51097 non-null int64
# Maximum Nights                51097 non-null int64
# Number of Reviews             51097 non-null int64
# First Reviewed                40749 non-null object
# Last Reviewed                 40749 non-null object
# Rating                        39778 non-null float64
# Reviews Per Month             40749 non-null float64
# Availability                  51097 non-null int64
# dtypes: float64(7), int64(8), object(9)
# memory usage: 9.7+ MB

# %%
#Lets take a look at the price fluctuation from neighborhood group to neighborhood group.
df['Neighborhood Group'].unique()
import seaborn as sns
sns.barplot('Neighborhood Group', 'Price', data = df)

# %%
df.groupby('Neighborhood Group')['Price'].mean()
# Out:
# Neighborhood Group
# Bronx             89.025964
# Brooklyn         125.086542
# Manhattan        215.083078
# Queens            97.342390
# Staten Island    104.528497
# Name: Price, dtype: float64

# %%
#Due to the pricing of specific accomodations being extremely large using the average based on its enighborhood reduces the size
#This also allows us to see the outlying prices.
x = df.groupby('Neighborhood')['Price'].mean()
sns.boxplot(x)

# %%
#Following Graph shows the most common pricing of accomodations as well as some of the outliers.
df['Price'].hist(bins=2000)
plt.xlim(0,1000)
plt.ylim(0,2500)
plt.xlabel("Price")
plt.ylabel("Number Of Accomodations")
plt.title("Accomodations vs Price")
plt.show()

# %%
#With this line plot you can see the correlation of availability and revies (popularity).
#The more available an accomodation is the more reviews it will have.
x = df['Availability']
y = df['Number of Reviews']
sns.lineplot(x,y)

# %%
#Now I would like to see the effect bathrooms, bedrooms, and beds have on the pricing
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot('Number of Bathrooms', 'Price', data = df)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot('Number of Bedrooms', 'Price', data = df)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot('Number of Beds', 'Price', data = df)

# %%
sns.barplot('Price', 'Property Type', data = df)
